# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinudeshmukh/Data-Science/blob/main/HierarchicalClusteringAssgn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("EastWestAirlines 1.xlsx")
df
# Out:
#        ID#  Balance  Qual_miles  ...  Flight_trans_12  Days_since_enroll  Award?
# 0        1    28143           0  ...                0               7000       0
# 1        2    19244           0  ...                0               6968       0
# 2        3    41354           0  ...                0               7034       0
# 3        4    14776           0  ...                0               6952       0
# 4        5    97752           0  ...                4               6935       1
# ...    ...      ...         ...  ...              ...                ...     ...
# 3994  4017    18476           0  ...                1               1403       1
# 3995  4018    64385           0  ...                0               1395       1
# 3996  4019    73597           0  ...                0               1402       1
# 3997  4020    54899           0  ...                1               1401       0
# 3998  4021     3016           0  ...                0               1398       0
#
# ...

# %%
df = df.drop(['ID#'],axis=1)

# %%
def myfun(i):
  x = (i-i.min())/(i.max()-i.min())
  return (x)

# %%
df_norm = myfun(df)
df_norm.head(40)
# Out:
#      Balance  Qual_miles  cc1_miles  ...  Flight_trans_12  Days_since_enroll  Award?
# 0   0.016508    0.000000       0.00  ...         0.000000           0.843742     0.0
# 1   0.011288    0.000000       0.00  ...         0.000000           0.839884     0.0
# 2   0.024257    0.000000       0.00  ...         0.000000           0.847842     0.0
# 3   0.008667    0.000000       0.00  ...         0.000000           0.837955     0.0
# 4   0.057338    0.000000       0.75  ...         0.075472           0.835905     1.0
# 5   0.009631    0.000000       0.00  ...         0.000000           0.836749     0.0
# 6   0.049808    0.000000       0.50  ...         0.000000           0.843019     0.0
# 7   0.012233    0.000000       0.00  ...         0.018868           0.836267     1.0
# 8   0.259850    0.000000       0.50  ...         0.226415           0.837473     1.0
# 9   0.061507    0.000000       0.50  ...         0.056604           0.835423     1.0
# ...

# %%
dendrogram = sch.dendrogram(sch.linkage(df_norm,method="single"))
# Out:
# Error in callback <function flush_figures at 0x7f9311b66048> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %%
 hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='single')

# %%
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='single', memory=None, n_clusters=4)

# %%
y_hc = hc.fit_predict(df_norm)
Clusters = pd.DataFrame(y_hc,columns=['Clusters'])

# %%
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %%
df['Clusters'] = Clusters

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  ...  Days_since_enroll  Award?  Clusters
# 0       28143           0          1  ...               7000       0         1
# 1       19244           0          1  ...               6968       0         1
# 2       41354           0          1  ...               7034       0         1
# 3       14776           0          1  ...               6952       0         1
# 4       97752           0          4  ...               6935       1         0
# ...       ...         ...        ...  ...                ...     ...       ...
# 3994    18476           0          1  ...               1403       1         0
# 3995    64385           0          1  ...               1395       1         0
# 3996    73597           0          3  ...               1402       1         0
# 3997    54899           0          1  ...               1401       0         1
# 3998     3016           0          1  ...               1398       0         1
#
# ...

# %%
df[df['Bonus_miles']<5000]
# Out:
#       Balance  Qual_miles  cc1_miles  ...  Days_since_enroll  Award?  Clusters
# 0       28143           0          1  ...               7000       0         1
# 1       19244           0          1  ...               6968       0         1
# 2       41354           0          1  ...               7034       0         1
# 3       14776           0          1  ...               6952       0         1
# 5       16420           0          1  ...               6942       0         1
# ...       ...         ...        ...  ...                ...     ...       ...
# 3992    11181           0          1  ...               1407       0         1
# 3993     3974           0          1  ...               1397       0         1
# 3995    64385           0          1  ...               1395       1         0
# 3997    54899           0          1  ...               1401       0         1
# 3998     3016           0          1  ...               1398       0         1
#
# ...

# %%
df[
   (5000< df[['Bonus_miles']] | df['Bonus_miles']< 10000)
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-028b4faad0fa> in <module>()
#       1 df[
# ----> 2    (5000< df[['Bonus_miles']] | df['Bonus_miles']< 10000)
#       3 ]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1332         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

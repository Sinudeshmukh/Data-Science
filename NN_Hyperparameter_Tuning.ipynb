# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinudeshmukh/Data-Science/blob/main/NN_Hyperparameter_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.data.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1  ...             6             7
# count  7.680000e+02  7.680000e+02  ...  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18  ...  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  ...  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  ... -1.189553e+00 -1.041549e+00
# 25%   -8.448851e-01 -6.852363e-01  ... -6.889685e-01 -7.862862e-01
# 50%   -2.509521e-01 -1.218877e-01  ... -3.001282e-01 -3.608474e-01
# 75%    6.399473e-01  6.057709e-01  ...  4.662269e-01  6.602056e-01
# max    3.906578e+00  2.444478e+00  ...  5.883565e+00  4.063716e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............ batch_size=10, epochs=10, score=0.779, total=   1.6s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.734, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.7s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.773, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.830, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.778, total=   1.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.0s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.753, total=   3.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    9.1s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.701, total=   3.3s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.779, total=   3.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.837, total=   3.0s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   18.5s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.771, total=   3.1s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.714, total=   5.6s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.662, total=   5.6s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.734, total=   5.5s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.797, total=   5.5s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.765, total=   5.5s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.766, total=   1.1s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.708, total=   0.8s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.760, total=   0.9s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.850, total=   0.9s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.758, total=   0.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.753, total=   1.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.708, total=   1.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.760, total=   1.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.850, total=   1.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.765, total=   2.1s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.747, total=   3.3s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.708, total=   3.1s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.740, total=   3.1s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.817, total=   3.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.745, total=   3.2s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.753, total=   0.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.727, total=   0.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.779, total=   0.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.830, total=   1.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.758, total=   0.7s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.727, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.688, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.760, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.804, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.791, total=   1.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.766, total=   2.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.695, total=   2.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.747, total=   2.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.758, total=   2.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.791, total=   2.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.7min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.778711485862732, using {'batch_size': 10, 'epochs': 10}
# 0.778711485862732,0.030640617215683282 with: {'batch_size': 10, 'epochs': 10}
# 0.7683218717575073,0.04360907797902261 with: {'batch_size': 10, 'epochs': 50}
# 0.7344962358474731,0.04578986171272833 with: {'batch_size': 10, 'epochs': 100}
# 0.7683218717575073,0.04574482542381044 with: {'batch_size': 20, 'epochs': 10}
# 0.7670316576957703,0.046016378657588265 with: {'batch_size': 20, 'epochs': 50}
# 0.7513793587684632,0.0357478711367399 with: {'batch_size': 20, 'epochs': 100}
# 0.7695951104164124,0.03446241919811082 with: {'batch_size': 40, 'epochs': 10}
# 0.7540191888809205,0.0422192164257252 with: {'batch_size': 40, 'epochs': 50}
# 0.7513623714447022,0.03177012944372366 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.760, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.701, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.753, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.810, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.1s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.725, total=   1.1s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.2s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.753, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.0s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.701, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    5.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.753, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.837, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.765, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.740, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.721, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.760, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.791, total=   1.0s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.745, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.721, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.714, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.630, total=   0.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.830, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.745, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.740, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.708, total=   1.0s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.766, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.830, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.752, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.734, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.721, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.753, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.810, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.758, total=   1.0s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.747, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.740, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.656, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.824, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.758, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.760, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.701, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.786, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.850, total=   1.1s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.771, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.740, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.727, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.760, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.732, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.752, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   36.9s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7735336542129516, using {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.750046682357788,0.036696212596473154 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7618198752403259,0.043382950473084395 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7513453960418701,0.023354967517787626 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7280197024345398,0.064155086672008 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7591970205307007,0.04032396422531398 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7552839398384095,0.03069263439165242 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7449113130569458,0.053506237804848755 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7735336542129516,0.04766339696222278 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7421865820884704,0.01205614890282306 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, init=uniform, score=0.649, total=   1.1s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.584, total=   0.9s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.8s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.647, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.4s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.351, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.584, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.0s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.8s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.745, total=   1.1s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.9s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.647, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.786, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.714, total=   1.1s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.773, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.830, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.647, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.747, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.701, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.747, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.817, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.719, total=   1.0s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.747, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.701, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.760, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.830, total=   1.1s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.771, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.760, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.727, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.740, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.817, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.765, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   1.0s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.766, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.675, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.760, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.830, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.771, total=   1.1s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.740, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.688, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.760, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.824, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.765, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.745, total=   1.0s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.647, total=   0.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   49.8s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7618198871612549, using {'activation_function': 'tanh', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.5914183855056763,0.1313092546244197 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7499702930450439,0.06336384836070022 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7461506009101868,0.03942276424868222 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7618198871612549,0.041570083781508484 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7617944240570068,0.030708692958081076 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7605211734771729,0.04948335894884922 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7553094029426575,0.04353637943064144 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ neuron1=4, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.669, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.727, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.5s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.784, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.732, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.0s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.753, total=   1.1s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.675, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    5.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.740, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.784, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.5s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.758, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.760, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.688, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.824, total=   1.0s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.784, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.747, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.682, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.721, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.804, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.758, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.747, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.708, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.753, total=   1.1s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.830, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.765, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.766, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.721, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.837, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.765, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.773, total=   1.0s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.708, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.824, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.771, total=   0.8s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.753, total=   0.8s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.714, total=   0.8s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.766, total=   0.8s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.824, total=   1.0s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.752, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.766, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.721, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.760, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.824, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.752, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   37.1s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7683133840560913, using {'neuron1': 8, 'neuron2': 8}
# 0.7344368100166321,0.03870195414967579 with: {'neuron1': 4, 'neuron2': 2}
# 0.7422629714012146,0.03640519103050947 with: {'neuron1': 4, 'neuron2': 4}
# 0.7618283629417419,0.04426131028980713 with: {'neuron1': 4, 'neuron2': 8}
# 0.7422884464263916,0.04047245536962957 with: {'neuron1': 8, 'neuron2': 2}
# 0.7605126976966858,0.03969060759660273 with: {'neuron1': 8, 'neuron2': 4}
# 0.7683133840560913,0.03786047997354478 with: {'neuron1': 8, 'neuron2': 8}
# 0.7670061945915222,0.03689074453488297 with: {'neuron1': 16, 'neuron2': 2}
# 0.7617859244346619,0.03539573540528393 with: {'neuron1': 16, 'neuron2': 4}
# 0.764383327960968,0.033427846560061106 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# 0.796875
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.351, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.3s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.5s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.6s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.8s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    6.9s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.1s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.3s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   1.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   10.7s remaining:    0.0s
# Streaming output truncated to the last 5000 lines.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.001, neuron1=16, neuron2=8, score=0.647, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2, score=0.584, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2, score=0.630, total=   3.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2, score=0.745, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=2, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4, score=0.584, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4, score=0.630, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4, score=0.745, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=4, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.649, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.584, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.630, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.647, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.647, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.630, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.649, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.647, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.649, total=   3.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.584, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.630, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.745, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.647, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.649, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.630, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.745, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.584, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.630, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.649, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.630, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.647, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.649, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.647, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.649, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.630, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.649, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.630, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.745, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.649, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.584, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.630, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.745, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.647, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.649, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.584, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.630, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.745, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.647, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.727, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.675, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.753, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.843, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.765, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.753, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.701, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.760, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.843, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.771, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.740, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.701, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.760, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.837, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.752, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.721, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.714, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.753, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.843, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.758, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.734, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.688, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.773, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.837, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.758, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.734, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.714, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.766, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.843, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.758, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.727, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.688, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.760, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.824, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.752, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.734, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.688, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.753, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.830, total=   6.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.765, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.727, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.721, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.760, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.817, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.752, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.734, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.727, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.779, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.791, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.752, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.734, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.682, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.753, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.797, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.778, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.740, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.708, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.747, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.850, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.752, total=   5.8s
# ...
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=4, neuron2=8, score=0.758, total=   3.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.727, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.649, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.760, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.817, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=2, score=0.771, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.721, total=   3.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.701, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.727, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.797, total=   3.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=4, score=0.758, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.701, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.701, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.786, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.850, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=8, neuron2=8, score=0.758, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.708, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.714, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.760, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.810, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=2, score=0.791, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.734, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.701, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.779, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.778, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.778, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.721, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.682, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.773, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.810, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.758, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.688, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.662, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.734, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.784, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.732, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.649, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.675, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.779, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.797, total=   3.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.725, total=   3.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.688, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.708, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.760, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.588, total=   3.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.765, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.708, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.669, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.714, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.699, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.797, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.714, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.662, total=   3.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.701, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.837, total=   3.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=50, init=zero, learning_rate=0.1, neuron1=8, neuron2=4

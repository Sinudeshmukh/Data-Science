# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinudeshmukh/PYTHON-CODES/blob/main/mul_lin_reg_assgn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
cars=pd.read_excel("Toyota.xlsx")

# %%
cars
# Out:
#         Id  ... Tow_Bar
# 0        1  ...       0
# 1        2  ...       0
# 2        3  ...       0
# 3        4  ...       0
# 4        5  ...       0
# ...    ...  ...     ...
# 1431  1438  ...       0
# 1432  1439  ...       0
# 1433  1440  ...       0
# 1434  1441  ...       0
# 1435  1442  ...       0
#
# [1436 rows x 38 columns]

# %%
cars.corr()
# Out:
#                         Id     Price  ...  Radio_cassette   Tow_Bar
# Id                1.000000 -0.738250  ...       -0.011611  0.159171
# Price            -0.738250  1.000000  ...       -0.043179 -0.172369
# Age_08_04         0.906132 -0.876590  ...        0.012857  0.188720
# Mfg_Month         0.043742 -0.018138  ...        0.032576 -0.042170
# Mfg_Year         -0.919523  0.885159  ...       -0.018844 -0.182206
# KM                0.273298 -0.569960  ...        0.015770  0.084153
# HP               -0.109375  0.314990  ...        0.019919  0.068271
# Met_Color        -0.079713  0.108905  ...        0.071530  0.148536
# Automatic         0.066265  0.033081  ...       -0.014150  0.018786
# cc               -0.117704  0.126389  ...       -0.000470  0.002725
# Doors            -0.130207  0.185326  ...       -0.008265  0.102292
# Cylinders              NaN       NaN  ...             NaN       NaN
# Gears            -0.043343  0.063104  ...        0.015397 -0.029357
# ...

# %%
cars.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
cars.shape
# Out:
# (1436, 38)

# %%
cars.drop(['Id','Model','Cylinders','Color'],axis=1,inplace=True)

# %%
cars.shape
# Out:
# (1436, 34)

# %%
cars
# Out:
#       Price  Age_08_04  Mfg_Month  ...  Metallic_Rim  Radio_cassette Tow_Bar
# 0     13500         23         10  ...             0               0       0
# 1     13750         23         10  ...             0               0       0
# 2     13950         24          9  ...             0               0       0
# 3     14950         26          7  ...             0               0       0
# 4     13750         30          3  ...             0               0       0
# ...     ...        ...        ...  ...           ...             ...     ...
# 1431   7500         69         12  ...             0               0       0
# 1432  10845         72          9  ...             0               0       0
# 1433   8500         71         10  ...             0               0       0
# 1434   7250         70         11  ...             0               0       0
# 1435   6950         76          5  ...             0               0       0
#
# [1436 rows x 34 columns]

# %%
cars1=pd.get_dummies(cars,columns=['Fuel_Type'])

# %%
cars1
# Out:
#       Price  Age_08_04  ...  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0     13500         23  ...                 1                 0
# 1     13750         23  ...                 1                 0
# 2     13950         24  ...                 1                 0
# 3     14950         26  ...                 1                 0
# 4     13750         30  ...                 1                 0
# ...     ...        ...  ...               ...               ...
# 1431   7500         69  ...                 0                 1
# 1432  10845         72  ...                 0                 1
# 1433   8500         71  ...                 0                 1
# 1434   7250         70  ...                 0                 1
# 1435   6950         76  ...                 0                 1
#
# [1436 rows x 36 columns]

# %%
cars2=cars1[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
cars2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
cars2.corr()
# Out:
#                   Price  Age_08_04        KM  ...     Gears  Quarterly_Tax    Weight
# Price          1.000000  -0.876590 -0.569960  ...  0.063104       0.219197  0.581198
# Age_08_04     -0.876590   1.000000  0.505672  ... -0.005364      -0.198431 -0.470253
# KM            -0.569960   0.505672  1.000000  ...  0.015023       0.278165 -0.028598
# HP             0.314990  -0.156622 -0.333538  ...  0.209477      -0.298432  0.089614
# cc             0.126389  -0.098084  0.102683  ...  0.014629       0.306996  0.335637
# Doors          0.185326  -0.148359 -0.036197  ... -0.160141       0.109363  0.302618
# Gears          0.063104  -0.005364  0.015023  ...  1.000000      -0.005452  0.020613
# Quarterly_Tax  0.219197  -0.198431  0.278165  ... -0.005452       1.000000  0.626134
# Weight         0.581198  -0.470253 -0.028598  ...  0.020613       0.626134  1.000000
#
# [9 rows x 9 columns]

# %%
import seaborn as sns

# %%
sns.set_context('talk')
sns.pairplot(cars2)

# %% [markdown]
# #Build Model

# %%
import statsmodels.formula.api as smf
model=smf.ols("Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=cars2).fit()

# %%
#coeeffs
model.params
# Out:
# Intercept       -5573.106358
# Age_08_04        -121.658402
# KM                 -0.020817
# HP                 31.680906
# cc                 -0.121100
# Doors              -1.616641
# Gears             594.319936
# Quarterly_Tax       3.949081
# Weight             16.958632
# dtype: float64

# %%
#tvalues and pvalues
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept        -3.948666
# Age_08_04       -46.511852
# KM              -16.621622
# HP               11.241018
# cc               -1.344222
# Doors            -0.040410
# Gears             3.016007
# Quarterly_Tax     3.014535
# Weight           15.879803
# dtype: float64
#  Intercept         8.241949e-05
# Age_08_04        3.354724e-288
# KM                7.538439e-57
# HP                3.757218e-28
# cc                1.790902e-01
# Doors             9.677716e-01
# Gears             2.606549e-03
# Quarterly_Tax     2.619148e-03
# Weight            2.048576e-52
# dtype: float64

# %%
#rsquared & adjrsquared
model.rsquared,model.rsquared_adj
# Out:
# (0.8637627463428192, 0.8629989775766963)

# %% [markdown]
# #Predict new values

# %%
newdata=pd.DataFrame({"Age_08_04":35,"KM":50000,"HP":190,"cc":2000,"Doors":3,"Gears":6,"Quarterly_Tax":180,"Weight":1300},index=[1])

# %%
newdata
# Out:
#    Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 1         35  50000  190  2000      3      6            180    1300

# %%
model.predict(newdata)
# Out:
# 1    21223.290252
# dtype: float64
